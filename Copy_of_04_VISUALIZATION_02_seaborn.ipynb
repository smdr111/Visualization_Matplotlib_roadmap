# %% [markdown]
# <a href="https://colab.research.google.com/github/smdr111/Visualization_Matplotlib_roadmap/blob/main/Copy_of_04_VISUALIZATION_02_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ### 4.2. Chiziqli grafiklar. `seaborn` kutubxonasi

# %% [markdown]
# `seaborn` `matplotlib` ustiga qurilgan kutubxonalardan bo'lib, grafiklar bilan ishlashni yana osonlashtiradi va muhimi chizmalarga ko'zga yoqadigan qilib chiroy beradi.
# ![](https://i.imgur.com/54BoIBW.png)
# `seaborn` to'lqi dokumentasiya: https://seaborn.pydata.org/index.html

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns # agar seaborn o'rnatilmagan bo'lsa pip install seaborn

# %% [markdown]
# Keling, amaliyot uchun ma'lumotlar yuklab olamiz.

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/museum_visitors.csv", index_col=0)
df.head()
# Out:
#             Avila Adobe  ...  America Tropical Interpretive Center
# Date                     ...
# 2014-01-01        24778  ...                                  6602
# 2014-02-01        18976  ...                                  5029
# 2014-03-01        25231  ...                                  8129
# 2014-04-01        26989  ...                                  2824
# 2014-05-01        36883  ...                                 10694
#
# [5 rows x 4 columns]

# %% [markdown]
# Yuqoridagi jadvalda AQSHdagi ba'zi muzeylarga turli sanalarda tashrif buyurganlar soni saqlangan.

# %%
df.shape
# Out:
# (59, 4)

# %% [markdown]
# `seaborn` da chiziqli grafik chizish uchun `.lineplot()` metodiga murojaat qilamiz.

# %%
sns.lineplot(data=df)
plt.show()

# %% [markdown]
# Ahamiyat bering, `seaborn` chiziqlarning rangi, shakli qo'shimcha ma'lumotlarni avtomat qo'yib ketdi.
#
# Solishtirish uchun, quyida to'g'ridan-to'g'ri matplotlib yordamida chizilgan grafikni ko'rishingiz mumkin.

# %%
plt.plot(df)
plt.show()

# %% [markdown]
# Keling, avvalgi darsda o'rgangan  bilimlarimiz bilan grafikni epaqaga keltiramiz:

# %%
plt.figure(figsize=(16,6))
plt.title("Muzeylarga tashrif grafigi")
plt.xlabel("Sana")
plt.ylabel("Odamlar soni")
sns.lineplot(data=df)
plt.show()

# %% [markdown]
# `x` o'qidagi sanalar ko'rinmay qoldi. Buni ham to'g'rilash mumkin:

# %%
plt.figure(figsize=(16,6))
plt.title("Muzeylarga tashrif grafigi")
plt.xlabel("Sana")
plt.xticks(rotation=90) # x o'qidagi yozuvlarni 90 gradusga aylantiramiz
plt.ylabel("Odamlar soni")
sns.lineplot(data=df)
plt.show()

# %% [markdown]
# **Chiziqli grafiklarning asosiy vazifasi biror jarayon/hodisani vaqt o'tishi o'zgarishini (tendensiyasini) kuzatish**
#
# Yuqoridagi grafikdan ham biz turli muzeylarga tashrif buyurganlar sonini chiroyli va muhimi tushunarli ko'rinishda ko'rishimiz va turli xulosalar qilishimiz mumkin.
#
# Misol uchun, muzeylar orasida Avila Adobe muzeyi juda mashur ekan. Firehouse Museumga esa 2014-yil 9-Yanvar kuni juda ko'p odam tashrig buyurgan (bu jadvaldagi xatolikka ham ishora qilishi mumkin)

# %% [markdown]
# Agar `df` ning barcha ustunlarini emas, tanlangan ustunlarning grafigini chizaman desangiz, buning ham imkoni bor:

# %%
df.head(1)
# Out:
#             Avila Adobe  ...  America Tropical Interpretive Center
# Date                     ...
# 2014-01-01        24778  ...                                  6602
#
# [1 rows x 4 columns]

# %% [markdown]
# Misol uchun, `Avila Adobe` muzeyi uchun grafik quyidagicha bo'ladi:

# %%
plt.figure(figsize=(16,6))
plt.title("Avila Adobe muzeyiga tashriflar")
plt.xlabel("Sana")
plt.xticks(rotation=90) # x o'qidagi yozuvlarni 90 gradusga aylantiramiz
plt.ylabel("Odamlar soni")
sns.lineplot(data=df['Avila Adobe'])
plt.show()

# %% [markdown]
# `.lineplot()` funksiyasiga ham qiymatlarni `x` va `y` ko'rinishida uzatish mumkin:

# %%
plt.figure(figsize=(16,6))
plt.xticks(rotation=90)

sns.lineplot(x=df.index, y=df['Chinese American Museum'])
plt.show()

# %% [markdown]
# Yoki bir nechta ustun uchun grafik chizish kerak bo'lsa:

# %%
plt.figure(figsize=(16,6))
plt.title("Muzeylarga tashriflar soni")
plt.xlabel("Sana")
plt.xticks(rotation=90) # x o'qidagi yozuvlarni 90 gradusga aylantiramiz
plt.ylabel("Odamlar soni")
sns.lineplot(data=df[['Avila Adobe','Chinese American Museum']])
plt.show()

# %% [markdown]
# Chiziqli (va umuman boshqa) grafiklarning turli parametrlari juda ham ko'p. Ularning barchasi bilan ushbu link orqali tanishishingiz mumkin: https://seaborn.pydata.org/generated/seaborn.lineplot.html
#
# ##Eslatma: Chiziqli grafiklarning asosiy vazifasi biror jarayon/hodisani vaqt o'tishi o'zgarishini (tendensiyasini) kuzatish
